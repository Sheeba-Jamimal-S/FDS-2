# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheeba-Jamimal-S/FDS-2/blob/main/FDS4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/pre_process_datasample - pre_process_datasample.xlsx - pre_process_datasample - pre_pr.csv')
df=df.iloc[:1:]

df.info()
df.Country.mode()

df.Country.mode()[0]
type(df.Country.mode())
type(df.Country.mode(0))
df['Country'] = df['Country'].fillna(df.Country.mode()[0])
df['Age'] = df['Age'].fillna(df.Age.median())
df['Salary'] = df['Salary'].fillna(round(df.Salary.mean()))
df
pd.get_dummies(df.Country)
updated_dataset=pd.concat([pd.get_dummies(df.Country),df.iloc[:,[1,2,3]]],axis=1)
df.info()
updated_dataset

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.Purchased=le.fit_transform(df.Purchased)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    1 non-null      object
#  1   Age        1 non-null      float64
#  2   Salary     1 non-null      float64
#  3   Purchased  1 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 164.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    1 non-null      object
#  1   Age        1 non-null      float64
#  2   Salary     1 non-null      float64
#  3   Purchased  1 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 164.0+ bytes
#   Country   Age   Salary  Purchased
# 0  France  44.0  72000.0          0
