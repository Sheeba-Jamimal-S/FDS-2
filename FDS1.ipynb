# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheeba-Jamimal-S/FDS-2/blob/main/FDS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1a)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
years = np.arange(2014, 2024)

job_postings = np.array([
    15000, 20000, 28000, 35000, 45000, 60000, 75000, 85000, 92000, 105000
])

np.random.seed(42)
job_postings = job_postings + np.random.randint(-5000, 5000, size=len(years))

# Ensure job postings are not negative
job_postings[job_postings < 0] = 0

df_jobs = pd.DataFrame({
    'Year': years,
    'Job_Postings': job_postings
})

display(df_jobs.head())
# Out:
#    Year  Job_Postings
# 0  2014         17270
# 1  2015         15860
# 2  2016         28390
# 3  2017         35191
# 4  2018         45734

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_jobs['Year'], df_jobs['Job_Postings'], marker='o', linestyle='-', color='skyblue')
plt.title('Trend of Data Science Job Postings Over the Last Decade')
plt.xlabel('Year')
plt.ylabel('Number of Job Postings')
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(df_jobs['Year'])
plt.tight_layout()
plt.show()

# %%
#1 b)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data for various data science roles and their approximate distribution
roles_data = {
    'Role': [
        'Data Scientist',
        'Data Engineer',
        'Data Analyst',
        'Machine Learning Engineer',
        'AI Engineer',
        'Business Intelligence Analyst',
        'Research Scientist'
    ],
    'Count': [
        45000, # Data Scientist
        30000, # Data Engineer
        25000, # Data Analyst
        20000, # Machine Learning Engineer
        12000, # AI Engineer
        8000,  # Business Intelligence Analyst
        5000   # Research Scientist
    ]
}

df_roles = pd.DataFrame(roles_data)

# Sort the DataFrame by count for better visualization
df_roles = df_roles.sort_values(by='Count', ascending=False)

display(df_roles)
# Out:
#                             Role  Count
# 0                 Data Scientist  45000
# 1                  Data Engineer  30000
# 2                   Data Analyst  25000
# 3      Machine Learning Engineer  20000
# 4                    AI Engineer  12000
# 5  Business Intelligence Analyst   8000
# 6             Research Scientist   5000

# %%
plt.figure(figsize=(14, 7))
sns.barplot(x='Count', y='Role', data=df_roles, palette='viridis')
plt.title('Distribution of Various Data Science Roles')
plt.xlabel('Number of Job Postings')
plt.ylabel('Data Science Role')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1469/2802103070.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='Role', data=df_roles, palette='viridis')

# %%
#1 c)
import pandas as pd

# Example of Structured Data: A DataFrame representing sales records
structured_data = pd.DataFrame({
    'OrderID': [1, 2, 3, 4],
    'CustomerName': ['Alice', 'Bob', 'Charlie', 'David'],
    'Product': ['Laptop', 'Mouse', 'Keyboard', 'Monitor'],
    'Quantity': [1, 2, 1, 1],
    'Price': [1200.00, 25.00, 75.00, 300.00],
    'OrderDate': pd.to_datetime(['2023-01-10', '2023-01-10', '2023-01-11', '2023-01-12'])
})

print("Structured Data Example (DataFrame):")
display(structured_data)
print("\nData Types:")
display(structured_data.info())
# Out:
# Structured Data Example (DataFrame):
#    OrderID CustomerName   Product  Quantity   Price  OrderDate
# 0        1        Alice    Laptop         1  1200.0 2023-01-10
# 1        2          Bob     Mouse         2    25.0 2023-01-10
# 2        3      Charlie  Keyboard         1    75.0 2023-01-11
# 3        4        David   Monitor         1   300.0 2023-01-12
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       4 non-null      int64
#  1   CustomerName  4 non-null      object
#  2   Product       4 non-null      object
#  3   Quantity      4 non-null      int64
#  4   Price         4 non-null      float64
#  5   OrderDate     4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 324.0+ bytes
# None

# %%
import json

# Example of Semi-structured Data: A list of JSON objects
semi_structured_data = [
    {
        "CustomerID": "C001",
        "Name": "Alice Smith",
        "Email": "alice@example.com",
        "Addresses": [
            {"Type": "Billing", "Street": "123 Main St", "City": "Anytown"},
            {"Type": "Shipping", "Street": "456 Oak Ave", "City": "Anytown"}
        ]
    },
    {
        "CustomerID": "C002",
        "Name": "Bob Johnson",
        "Email": "bob@example.com",
        "Phone": "555-1234", # Optional field
        "Addresses": [
            {"Type": "Billing", "Street": "789 Pine Ln", "City": "Otherville"}
        ]
    }
]

print("Semi-structured Data Example (JSON):")
print(json.dumps(semi_structured_data, indent=2))

# Converting to DataFrame for partial analysis (often done with semi-structured data)
df_semi_structured = pd.json_normalize(semi_structured_data)
print("\nSemi-structured Data as DataFrame (after normalization):")
display(df_semi_structured)
# Out:
# Semi-structured Data Example (JSON):
# [
#   {
#     "CustomerID": "C001",
#     "Name": "Alice Smith",
#     "Email": "alice@example.com",
#     "Addresses": [
#       {
#         "Type": "Billing",
#         "Street": "123 Main St",
#         "City": "Anytown"
#       },
#       {
#         "Type": "Shipping",
#         "Street": "456 Oak Ave",
#         "City": "Anytown"
#       }
#     ]
#   },
#   {
#     "CustomerID": "C002",
#     "Name": "Bob Johnson",
#     "Email": "bob@example.com",
#     "Phone": "555-1234",
#     "Addresses": [
#       {
#         "Type": "Billing",
#         "Street": "789 Pine Ln",
#         "City": "Otherville"
#       }
#     ]
#   }
# ]
#
# Semi-structured Data as DataFrame (after normalization):
#   CustomerID         Name              Email  \
# 0       C001  Alice Smith  alice@example.com
# 1       C002  Bob Johnson    bob@example.com
#
#                                            Addresses     Phone
# ...

# %%
# Example of Unstructured Data: Text and image (conceptual representation)

unstructured_text = """The quick brown fox jumps over the lazy dog. This is a sample paragraph
containing unstructured text data. It doesn't follow any specific format,
making it challenging for traditional database systems to process directly.
Natural Language Processing (NLP) techniques are often used to extract insights from such data.
"""

unstructured_image_description = "An image file, e.g., 'image.jpg', where the content (pixels) itself is unstructured."

print("Unstructured Data Example (Text):")
print(unstructured_text)

print("\nUnstructured Data Example (Image - conceptual):")
print(unstructured_image_description)

# While we can't directly display an image without loading it, we can show a placeholder or a path.
# For actual processing, one would use libraries like Pillow (PIL) for images or NLTK/SpaCy for text.
# import PIL.Image
# img = PIL.Image.open('path/to/image.jpg')
# display(img)
# Out:
# Unstructured Data Example (Text):
# The quick brown fox jumps over the lazy dog. This is a sample paragraph
# containing unstructured text data. It doesn't follow any specific format,
# making it challenging for traditional database systems to process directly.
# Natural Language Processing (NLP) techniques are often used to extract insights from such data.
#
#
# Unstructured Data Example (Image - conceptual):
# An image file, e.g., 'image.jpg', where the content (pixels) itself is unstructured.

# %%
#1 d)
# !pip install cryptography

# %%
from cryptography.fernet import Fernet

# 1. Generate a Fernet key
# This key is crucial. It must be kept secret and used for both encryption and decryption.
# In a real-world scenario, you would securely store and retrieve this key.
key = Fernet.generate_key()
f = Fernet(key)

print(f"Generated Fernet Key: {key.decode()}")

# 2. Define sensitive data to be encrypted
sensitive_data = "This is a top secret message that needs to be encrypted."
print(f"\nOriginal Sensitive Data: {sensitive_data}")

# Convert the string data to bytes, as Fernet works with bytes
sensitive_data_bytes = sensitive_data.encode()

# 3. Encrypt the data
encrypted_data = f.encrypt(sensitive_data_bytes)
print(f"Encrypted Data: {encrypted_data.decode()}")

# 4. Decrypt the data
decrypted_data_bytes = f.decrypt(encrypted_data)

# Convert the decrypted bytes back to a string
decrypted_data = decrypted_data_bytes.decode()
print(f"Decrypted Data: {decrypted_data}")

# Verification
if sensitive_data == decrypted_data:
    print("\nEncryption and Decryption successful! Original and decrypted data match.")
else:
    print("\nError: Original and decrypted data do NOT match.")
# Out:
# Generated Fernet Key: w9gGqQ9G_MKxZUvPOulElodVmLHr5_7N1i-uZWY47Lg=
#
# Original Sensitive Data: This is a top secret message that needs to be encrypted.
# Encrypted Data: gAAAAABqqgffGH0ek93Ctg4zJtf3XbsZpp9PH8ltfwy-H_AcWC7gqFQnlX7ZeiW1VTWGXhfoi3LsQusEEpg3zIc3nmjE4f2waoxEiNCZoctZaqx1bXKroABSthhYrKHGQuOZdzx0M49gQiMl5Dh45htnQyqoK8k7cg==
# Decrypted Data: This is a top secret message that needs to be encrypted.
#
# Encryption and Decryption successful! Original and decrypted data match.
